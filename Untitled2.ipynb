# %% [markdown]
# <a href="https://colab.research.google.com/github/mandalenikita368/Signalfiltering/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

# Sample Data
X = np.array([1, 2, 3, 4, 5])       # Years of experience
y = np.array([30000, 35000, 40000, 45000, 50000])  # Salary

# Mean values
mean_x = np.mean(X)
mean_y = np.mean(y)

# Calculate slope (m) and intercept (b)
numerator = np.sum((X - mean_x) * (y - mean_y))
denominator = np.sum((X - mean_x) ** 2)
m = numerator / denominator
b = mean_y - m * mean_x

print(f"Equation: y = {m:.2f}x + {b:.2f}")

# Predict
y_pred = m * X + b

# Plot
plt.scatter(X, y, color="blue", label="Actual")
plt.plot(X, y_pred, color="red", label="Prediction Line")
plt.xlabel("Years of Experience")
plt.ylabel("Salary")
plt.legend()
plt.title("Linear Regression from Scratch")
plt.grid(True)
plt.show()
# Out:
# Equation: y = 5000.00x + 25000.00

# %% [markdown]
# # New section
